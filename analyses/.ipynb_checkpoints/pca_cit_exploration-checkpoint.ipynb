# %% [markdown]
# # Testing PCA for Causal Inference
# I need to get a baseline for what causal inference I can do using genotype PCs. So to start I'll just run a small simulation under three scenarios
#
# 1. Null case (no association between variables)
# 1. Full causal mediation
# 1. Independent association of genotype PC with mediator and response
#
# First I'll just import some of the code I've written to generate datasets and run inference, then I'll construct the PCs and run a causal inference test on varying numbers of PCs for each set.

# %%
import cit
import joblib 
import data_model as dm
import multiprocessing as mp
import numpy as np
import scipy as sp
import pandas as pd

# %%
import warnings
warnings.filterwarnings(action='once')
def to_df(results):
    '''Merge result dictionary to a pd.DataFrame'''
    out_rows = []
    for res in results:
        cur_row = {}
        for j in range(1,5):
            cur_test = 'test{}'.format(j)
            cur_p = 'p{}'.format(j)
            for key in res[cur_test]:
                if key in ['rss', 'r2']: #single value for test
                    cur_key = '{}_{}'.format(cur_test,key)
                    cur_row[cur_key] = res[cur_test][key]
                else:
                    for k in range(len(res[cur_test][key])):
                        cur_key = '{}_{}{}'.format(cur_test,key,k)
                        cur_row[cur_key] = res[cur_test][key][k]
            cur_row[cur_p] = res[cur_p]
        cur_row['omni_p'] = res['omni_p']
        out_rows.append(cur_row)
    return pd.DataFrame(out_rows)

# %% [markdown]
# ## Null Case

# %%
NUM_SAMPLES = 100
null_data = [dm.generate_null(n=500) for i in range(NUM_SAMPLES)]
SVDs = [np.linalg.svd(genotype, full_matrices=False, compute_uv=True) for (_,_,genotype) in null_data]
PCs = [U@np.diag(D) for (U,D,Vh) in SVDs]

# %%
import importlib as imp
imp.reload(cit)
null_results = []
for i in range(1,6):
    args = [(trait,gene_exp, Z[:, 0:i], 100) for ((trait, gene_exp, _), Z) in zip(null_data, PCs)]
    with mp.Pool(processes=4) as pool:
        # %time null_result = pool.starmap(cit.cit, args)
    null_results.append(null_result)
# Out:
# (array([62.45983416]), 1879065.2317911393, 1879065.2317911389, array([61.30359258]), array([1.01886091])) (array([11.73429944, 99.46183278]), 49418.47117749621, 1879065.2317911389, array([12.97441424, 16.34622547]), array([0.90441844, 0.71785988, 7.66599793, 6.08469723])) 18437.723083601035
# (array([-0.2041362 ,  0.10006083]), 4.623143275211819, 18818.141596747635, array([0.13727581, 0.00156855]), array([  -1.48705145, -130.14343755,    0.72890353,   63.79201721])) (array([-0.1965866 ,  0.0993324 ,  0.07440783]), 4.596213110667739, 18818.141596747635, array([0.16870846, 0.00964396, 0.97207368]), array([ -1.16524446, -20.38442603,  -0.20223426,   0.58878135,
#         10.29995879,   0.10218608,   0.44104383,   7.71548419,
#          0.07654546])) 2.9120259344248804
# (array([2.05496466, 9.99146585]), 461.63898519824994, 1879065.2317911389, array([1.34903809, 0.15662565]), array([ 1.52328142, 13.12023109,  7.40636304, 63.79201721])) (array([2.0701728 , 9.97320131, 0.18669177]), 461.47037897489054, 1879065.2317911389, array([1.56597136, 0.96827585, 9.76697995]), array([ 1.3219736 ,  2.13799901,  0.21195629,  6.36869969, 10.29995879,
#         1.02111414,  0.11921787,  0.19280846,  0.01911459])) 0.18158758790926324
# (array([66.64637273]), 2269557.3591626165, 2269557.359162615, array([67.37295242]), array([0.98921556])) (array([ 11.37295847, 100.49711684]), 50154.76850099734, 2269557.359162615, array([13.0134853 , 15.10746766]), array([0.8739364 , 0.75280376, 7.72253662, 6.6521484 ])) 22037.037019271815
# (array([56.40608086]), 1784928.241819668, 1784928.241819668, array([59.74827599]), array([0.94406207])) (array([ 11.3892049 , 100.03750214]), 46124.798213296875, 1784928.241819668, array([12.08331724, 16.29314164]), array([0.94255614, 0.69901834, 8.27897672, 6.13985346])) 18773.50467554661
# (array([-0.19865292,  0.10004087]), 5.041571123720491, 17868.9174927378, array([0.13809336, 0.00168063]), array([  -1.43854078, -118.20133792,    0.72444377,   59.52575296])) (array([-0.19406668,  0.09959102,  0.04619562]), 5.031989478000287, 17868.9174927378, array([0.17343518, 0.01044486, 1.0586456 ]), array([ -1.11895801, -18.58011304,  -0.183316  ,   0.5742262 ,
#          9.53493121,   0.094074  ,   0.26635669,   4.42280881,
#          0.04363653]))(array([-0.18890268,  0.09987227]), 4.827071212986623, 22642.458157993857, array([0.13820701, 0.00145838]), array([  -1.36680962, -129.52894771,    0.72262807,   68.48155861])) (array([-0.17773069,  0.09876874,  0.11340761]), 4.764613747541684, 22642.458157993857, array([0.16845027, 0.0097467 , 0.99052143]), array([ -1.05509299, -18.23495532,  -0.17943145,   0.58633768,
#         10.13355367,   0.09971388,   0.67324092,  11.6354844 ,
#          0.11449284])) 0.9463608665640466
# (array([2.00107191, 9.99309426]), 503.60312456132243, 1784928.241819668, array([1.35740756, 0.1678785 ]), array([ 1.47418651, 11.9197627 ,  7.36189671, 59.52575296])) (array([2.05134616, 9.93182275, 0.62956404]), 501.8206140229395, 1784928.241819668, array([ 1.59611627,  1.041625  , 10.56326344]), array([1.28521099, 1.96937109, 0.19419625, 6.22249327, 9.53493121,
#        0.94022295, 0.39443495, 0.60440566, 0.05959939])) 6.5149793815186925
#  1.7653872974134728
# (array([ 1.90524764, 10.01065506]), 483.8394717654834, 2269557.359162615, array([1.3643398, 0.1461803]), array([ 1.39646123, 13.0335455 ,  7.33736203, 68.48155861])) (array([ 1.89179206, 10.02701647, -0.16792238]), 483.7042699595023, 2269557.359162615, array([ 1.58387037,  0.98948669, 10.04401382]), array([ 1.19441091,  1.91189238,  0.18835021,  6.33070524, 10.13355367,
#         0.99830771, -0.10602028, -0.16970656, -0.01671865])) 0.1389181401648927
# (array([61.58780432]), 1910474.9306881956, 1910474.930688195, array([61.81383228]), array([0.99634341])) (array([11.97590641, 99.2237958 ]), 49701.57823392661, 1910474.930688195, array([12.85091377, 16.21639027]), array([0.93191088, 0.7385063 , 7.72114711, 6.11873507])) 18644.58156963874
# (array([-0.18964514,  0.09993863]), 5.191689460169151, 19086.500596891146, array([0.14384353, 0.00164848]), array([  -1.31841273, -115.04242807,    0.69477323,   60.62471745])) (array([-0.1891506 ,  0.0998922 ,  0.00473028]), 5.191579441965077, 19086.500596891146, array([0.17953136, 0.01022032, 1.02755347]), array([-1.05357969e+00, -1.85072997e+01, -1.84078594e-01,  5.56405296e-01,
#         9.77387819e+00,  9.72136283e-02,  2.63479376e-02,  4.62830844e-01,
#         4.60344039e-03])) 0.010532256712250424
# (array([ 1.91385214, 10.0034186 ]), 519.6653263504397, 1910474.930688195, array([1.41711362, 0.16500561]), array([ 1.35052837, 11.59870939,  7.05900958, 60.62471745])) (array([1.99799655, 9.90708355, 0.98105691]), 514.8891556767012, 1910474.930688195, array([ 1.65922717,  1.01362871, 10.18617554]), array([1.204173  , 1.97113255, 0.19614786, 5.97090244, 9.77387819,
#        0.9726009 , 0.59127341, 0.96786615, 0.09631259])) 4.610228820469726
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda2/envs/tf_vae/lib/python3.6/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     272         `func` and (a, b) becomes func(a, b).
#     273         '''
# --> 274         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     275
#     276     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/anaconda2/envs/tf_vae/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda2/envs/tf_vae/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda2/envs/tf_vae/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda2/envs/tf_vae/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
import pickle
with open('3_5_2019_PCA_null.dat','wb') as f:
    pickle.dump(PCs, f)
    pickle.dump(null_data, f)
    pickle.dump(null_results,f)

# %%
test = to_df(null_results)
test.filter(regex = 'p')
# Out:
#    omni_p            p1        p2        p3   p4  test1_p0      test1_p1  \
# 0     1.0  1.110223e-16  0.010995  0.709518  1.0  0.191287  3.811862e-11
# 1     1.0  1.110223e-16  0.088546  0.670197  1.0  0.183105  1.164912e-09
# 2     1.0  1.110223e-16  0.331121  0.184564  1.0  0.173182  8.445725e-10
# 3     1.0  1.110223e-16  0.918301  0.032265  1.0  0.175917  9.554985e-10
# 4     1.0  1.110223e-16  0.005545  0.557278  1.0  0.170181  5.372109e-10
# 5     1.0  1.110223e-16  0.115837  0.537427  1.0  0.167269  1.420746e-09
# 6     1.0  1.110223e-16  0.004645  0.517948  1.0  0.186132  5.313568e-09
# 7     1.0  1.110223e-16  0.047777  0.909885  1.0  0.175768  2.497311e-09
# 8     1.0  1.110223e-16  0.011260  0.943617  1.0  0.163724  4.054744e-10
# 9     1.0  1.110223e-16  0.016817  0.899080  1.0  0.172542  2.193259e-09
#
#    test2_p0  test2_p1  test2_p2  test3_p0  test3_p1  test3_p2  test4_p0  \
# 0  0.854053       0.0  0.454447  0.116443       0.0  0.506666  0.116443
# 1  0.877761       0.0  0.469508  0.093392       0.0  0.492379  0.093392
# 2  0.868151       0.0  0.482606  0.099658       0.0  0.476249  0.099658
# 3  0.853707       0.0  0.498164  0.114547       0.0  0.461656  0.114547
# 4  0.852141       0.0  0.450304  0.116436       0.0  0.510503  0.116436
# 5  0.859509       0.0  0.471849  0.108959       0.0  0.488963  0.108959
# 6  0.846459       0.0  0.449278  0.123206       0.0  0.511570  0.123206
# 7  0.860579       0.0  0.464556  0.109838       0.0  0.497975  0.109838
# 8  0.855244       0.0  0.454596  0.109167       0.0  0.501266  0.109167
# 9  0.840494       0.0  0.457178  0.126928       0.0  0.502270  0.126928
#
#    test4_p1  test4_p2
# 0       0.0  0.506666
# 1       0.0  0.492379
# 2       0.0  0.476249
# 3       0.0  0.461656
# 4       0.0  0.510503
# 5       0.0  0.488963
# 6       0.0  0.511570
# 7       0.0  0.497975
# 8       0.0  0.501266
# 9       0.0  0.502270
