# %% [markdown]
# # Testing new training
# I've added a warm-up period and batch normalization after every layer except for output layers a la
# >Sønderby, Casper Kaae, et al. How to Train Deep Variational Autoencoders and Probabilistic Ladder Networks. no. Icml, 2016, http://arxiv.org/abs/1602.02282.
#
# Additionally I'm experimenting with the same architecture *without* using any sort of variational inference (i.e. just a
# regular autoencoder with $\mathcal{NLL}$ loss. I'm using this space to test small examples since I have no GPU access for now.
#
# First we'll load up some of the relevant packages and switch to where I'm keeping the python source code for this project:

# %%
import os
os.chdir("../scripts")
import data_model as dm
import vae_torch as vt

# %%
import numpy as np
import torch 
import pandas as pd
torch.manual_seed(0)
np.random.seed(0)
trait,gene_exp,genotype = dm.generate_caus1(500,300)

# %% [markdown]
# ## Variational Stuff
# ### Baseline: the training I've already been using

# %%
lv_baseline = dm.reduce_genotype(genotype, "mmdvae",1,'testing',vae_depth=5,model_dir="/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-42061ac070df> in <module>
# ----> 1 lv_baseline = dm.reduce_genotype(genotype, "mmdvae",1,'testing',vae_depth=5,model_dir="/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/")
#
# /project/6003095/wcasazza/vaecit/scripts/data_model.py in reduce_genotype(genotype, lv_method, num_latent, state_name, vae_depth, model_dir)
#     285                 model = vt.train_mmd_vae(torch.Tensor(stats.zscore(genotype)), params, save_loss=plot_name, warmup=True)
#     286             else:
# --> 287                 model = vt.train_mmd_vae(torch.Tensor(stats.zscore(genotype)), params, save_loss=plot_name)
#     288             torch.save(model.state_dict(), fname)
#     289         latent_genotype = model.encode(torch.Tensor(stats.zscore(genotype))).detach()
#
# /project/6003095/wcasazza/vaecit/scripts/vae_torch.py in train_mmd_vae(genotype, params, verbose, plot_loss, save_loss, warmup)
#     148         plt.xlabel("Epoch")
#     149         plt.ylabel("Loss")
# --> 150         plt.savefig(save_loss)
#     151         plt.close()
#     152     del genotype
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     519
#     520         with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
#     523                             self.figure.dpi, metadata=metadata)
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     405 def open_file_cm(path_or_file, mode="r", encoding=None):
#     406     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 407     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     408     if opened:
#     409         with fh:
#
# /scratch/wcasazza/tensorflow/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     390             fh = bz2.BZ2File(fname, flag)
#     391         else:
# --> 392             fh = open(fname, flag, encoding=encoding)
#     393         opened = True
#     394     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/testing_mmdvaeloss_5_depth.png'

# %% [markdown]
#   ![image.png](attachment:image.png) <!--![testing_mmdvaeloss_5_depth.png](tmp/testing_mmdvaeloss_5_depth.png)-->

# %%
lv_batch = dm.reduce_genotype(genotype, "mmdvae_batch",1,'testing',vae_depth=5,model_dir="/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/")

# %% [markdown]
# ![testing_mmdvae_batchloss_5_depth.png](tmp/testing_mmdvae_batchloss_5_depth.png)

# %%
lv_warmup = dm.reduce_genotype(genotype, "mmdvae_warmup",1,'testing',vae_depth=5,model_dir="/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/")

# %% [markdown]
# ![testing_mmdvae_warmuploss_5_depth.png](tmp/testing_mmdvae_warmuploss_5_depth.png)

# %%
lv_batch_warmup = dm.reduce_genotype(genotype, "mmdvae_batch_warmup",1,'testing',vae_depth=5,model_dir="/home/wcasazza/project/def-saram/wcasazza/vaecit/analyses/tmp/")

# %% [markdown]
# ![testing_mmdvae_batch_warmuploss_5_depth.png](tmp/testing_mmdvae_batch_warmuploss_5_depth.png)

# %% [markdown]
# ## No variational loss
# Just a plain autoencoder

# %%
lv_no_var = dm.reduce_genotype(genotype, "ae",1,'testing',vae_depth=5,model_dir="~/projects/def-saram/wcasazza/vaecit/analyses/tmp/")

# %% [markdown]
# ![testing_aeloss_5_depth.png](tmp/testing_aeloss_5_depth.png)

# %%
lv_no_var_batch = dm.reduce_genotype(genotype, "ae_batch",1,'testing',vae_depth=5,model_dir="~/projects/def-saram/wcasazza/vaecit/analyses/tmp/")

# %% [markdown]
# ![testing_ae_batchloss_5_depth.png](tmp/testing_ae_batchloss_5_depth.png)
