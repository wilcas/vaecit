# %% [markdown]
# # Exploring tensorflow
# I am getting confused when manipulating examples using tensorflow, so I am going to try to build up a VAE and train it line by line instead.

# %%
import tensorflow as tf
import numpy as np
tf.enable_eager_execution()

# %% [markdown]
# ## VAE module
# The variational autoencoder will expect a genotype vector as input. The idea is to learn genotype-set specific information from a sample by reducing it and then building it back up from a random generator. the structure of the program will be as follows:
#
# 1. VAE class
#     1. Model structure
#     1. training methods
# 1. example data training
# 1. data output

# %%
class VAE(tf.keras.Model):
    
    def __init__(self, n_latent=2, output_size=10): # default 2 latent dimensions
        super(VAE,self).__init__() # inherit Model functions
        self.n_latent=n_latent
        self.encode_net = tf.keras.Sequential(
            [
                tf.keras.layers.Dense(128,activation=tf.nn.relu),
                tf.keras.layers.Dense(256,activation=tf.nn.relu),
                tf.keras.layers.Dense(2*n_latent) #no Activation
            ]
        )
        self.decode_net = tf.keras.Sequential(
            [
                tf.keras.layers.InputLayer(input_shape=(n_latent,)),
                tf.keras.layers.Dense(256,activation=tf.nn.relu),
                tf.keras.layers.Dense(128,activation=tf.nn.relu),
                tf.keras.layers.Dense(output_size) #no Activation
            ]
        )
    
    def call(self, data):
        mean,logvar = self.encode(data)
        z = self.reparameterize(mean, logvar)
        return self.decode(z)

    def sample(self, eps=None):
        if eps is None:
            eps = tf.random.normal(shape=(100, self.n_latent))
        return self.decode(eps, apply_sigmoid=True)

    def encode(self, x):
        mean, logvar = tf.split(self.encode_net(x), num_or_size_splits=2, axis=1)
        return mean, logvar

    def reparameterize(self, mean, logvar):
        eps = tf.random.normal(shape=mean.shape)
        return eps * tf.exp(logvar * .5) + mean

    def decode(self, z, apply_sigmoid = False):
        logits = self.decode_net(z)
        if apply_sigmoid:
            return tf.sigmoid(logits)
        else:
            return logits
        
    def total_loss(self, x,y):
        mean, logvar = self.encode(x)
        z = self.reparameterize(mean, logvar)
        x_logit = self.decode(z)

        cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
        logpx_z = -tf.reduce_sum(cross_ent)
        logpz = log_normal_pdf(z, 0., 0.)
        logqz_x = log_normal_pdf(z, mean, logvar)
        return -tf.reduce_mean(logpx_z + logpz - logqz_x)
    
def log_normal_pdf(sample, mean, logvar, raxis=1):
    log2pi = tf.math.log(2. * np.pi)
    return tf.reduce_sum(
        -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
        axis=raxis
    )

# %% [markdown]
# ### Generate some data

# %%
(train_images, _), (test_images, _) = tf.keras.datasets.mnist.load_data()
train_images = train_images.astype('float32') / 255
train_images = train_images.reshape((train_images.shape[0], 28 * 28))
test_images = test_images.astype('float32') / 255
test_images = test_images.reshape((test_images.shape[0], 28 * 28))


# Binarization
train_images[train_images >= .5] = 1.
train_images[train_images < .5] = 0.
test_images[test_images >= .5] = 1.
test_images[test_images < .5] = 0.


# train_data = np.random.binomial(2,0.25, size=(10000,1000)).astype(np.float32)
# test_data = np.random.binomial(2,0.25, size=(10000,1000)).astype(np.float32)

# %% [markdown]
# ### Training
# Only 3 lines!

# %%
model = VAE(n_latent=2, output_size=28*28)
model.compile(loss = model.total_loss, optimizer = tf.train.AdamOptimizer(1e-4), metrics=['accuracy', 'binary_crossentropy'])

# %%
with(tf.device('/gpu:0')):
    train_history = model.fit(train_images,train_images, epochs=100, batch_size=100,validation_data=(test_images, test_images), callbacks=[tf.keras.callbacks.TensorBoard()])
# Out:
# Epoch 1/100
# 600/600 [==============================] - 13s 21ms/step - loss: 24796.5283 - acc: 8.8333e-04 - binary_crossentropy: 1.7325 - val_loss: 20341.9994 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.8569
# Epoch 2/100
# 600/600 [==============================] - 13s 21ms/step - loss: 19454.2788 - acc: 2.0000e-04 - binary_crossentropy: 1.6749 - val_loss: 18500.0915 - val_acc: 1.0000e-04 - val_binary_crossentropy: 1.4897
# Epoch 3/100
# 600/600 [==============================] - 13s 21ms/step - loss: 18248.9630 - acc: 1.0000e-04 - binary_crossentropy: 1.5134 - val_loss: 17879.1278 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.4855
# Epoch 4/100
# 600/600 [==============================] - 13s 21ms/step - loss: 17604.8123 - acc: 1.6667e-04 - binary_crossentropy: 1.4412 - val_loss: 17261.0299 - val_acc: 2.0000e-04 - val_binary_crossentropy: 1.4414
# Epoch 5/100
# 600/600 [==============================] - 13s 21ms/step - loss: 17179.8578 - acc: 5.0000e-05 - binary_crossentropy: 1.4158 - val_loss: 16918.7666 - val_acc: 1.0000e-04 - val_binary_crossentropy: 1.4282
# Epoch 6/100
# 600/600 [==============================] - 13s 22ms/step - loss: 16854.3801 - acc: 3.6667e-04 - binary_crossentropy: 1.3804 - val_loss: 16624.6703 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.3695
# Epoch 7/100
# 600/600 [==============================] - 13s 22ms/step - loss: 16603.1611 - acc: 5.3333e-04 - binary_crossentropy: 1.3319 - val_loss: 16420.6118 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.2969
# Epoch 8/100
# 600/600 [==============================] - 13s 21ms/step - loss: 16422.4297 - acc: 4.8333e-04 - binary_crossentropy: 1.2831 - val_loss: 16301.4728 - val_acc: 2.0000e-04 - val_binary_crossentropy: 1.2789
# Epoch 9/100
# 600/600 [==============================] - 13s 21ms/step - loss: 16263.9111 - acc: 2.8333e-04 - binary_crossentropy: 1.2513 - val_loss: 16126.2276 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.2497
# Epoch 10/100
# 600/600 [==============================] - 13s 21ms/step - loss: 16118.4534 - acc: 3.8333e-04 - binary_crossentropy: 1.2264 - val_loss: 16019.5456 - val_acc: 1.0000e-04 - val_binary_crossentropy: 1.2150
# Epoch 11/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15990.5579 - acc: 2.6667e-04 - binary_crossentropy: 1.2099 - val_loss: 15923.2417 - val_acc: 3.0000e-04 - val_binary_crossentropy: 1.2030
# Epoch 12/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15878.0493 - acc: 2.8333e-04 - binary_crossentropy: 1.1946 - val_loss: 15819.9075 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1875
# Epoch 13/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15772.9264 - acc: 2.1667e-04 - binary_crossentropy: 1.1791 - val_loss: 15728.4585 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1750
# Epoch 14/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15670.0948 - acc: 2.6667e-04 - binary_crossentropy: 1.1648 - val_loss: 15630.2967 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.1836
# Epoch 15/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15564.5700 - acc: 3.8333e-04 - binary_crossentropy: 1.1498 - val_loss: 15531.4499 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1434
# Epoch 16/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15465.1519 - acc: 3.5000e-04 - binary_crossentropy: 1.1385 - val_loss: 15440.6591 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1557
# Epoch 17/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15367.4960 - acc: 4.3333e-04 - binary_crossentropy: 1.1255 - val_loss: 15342.6490 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1372
# Epoch 18/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15276.9271 - acc: 5.0000e-04 - binary_crossentropy: 1.1154 - val_loss: 15251.9715 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.1201
# Epoch 19/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15188.3564 - acc: 4.8333e-04 - binary_crossentropy: 1.1021 - val_loss: 15180.3274 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1174
# Epoch 20/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15106.8124 - acc: 5.8333e-04 - binary_crossentropy: 1.0930 - val_loss: 15115.6373 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.1208
# Epoch 21/100
# 600/600 [==============================] - 13s 21ms/step - loss: 15035.0042 - acc: 5.6667e-04 - binary_crossentropy: 1.0846 - val_loss: 15086.0233 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.1389
# Epoch 22/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14966.6851 - acc: 5.3333e-04 - binary_crossentropy: 1.0803 - val_loss: 15019.5768 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0779
# Epoch 23/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14907.9464 - acc: 5.1667e-04 - binary_crossentropy: 1.0704 - val_loss: 14960.8140 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0948
# Epoch 24/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14850.2554 - acc: 6.3333e-04 - binary_crossentropy: 1.0672 - val_loss: 14911.6651 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0995
# Epoch 25/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14799.4193 - acc: 6.3333e-04 - binary_crossentropy: 1.0610 - val_loss: 14841.7277 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0756
# Epoch 26/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14750.0719 - acc: 5.3333e-04 - binary_crossentropy: 1.0545 - val_loss: 14820.8507 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.0834
# Epoch 27/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14704.7583 - acc: 6.0000e-04 - binary_crossentropy: 1.0504 - val_loss: 14788.2165 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0934
# Epoch 28/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14660.1332 - acc: 6.0000e-04 - binary_crossentropy: 1.0454 - val_loss: 14741.4056 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0705
# Epoch 29/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14621.7423 - acc: 7.5000e-04 - binary_crossentropy: 1.0412 - val_loss: 14699.0552 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.0575
# Epoch 30/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14583.3126 - acc: 6.3333e-04 - binary_crossentropy: 1.0364 - val_loss: 14669.3203 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0416
# Epoch 31/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14547.0163 - acc: 6.5000e-04 - binary_crossentropy: 1.0319 - val_loss: 14633.9127 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.0297
# Epoch 32/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14509.9320 - acc: 8.3333e-04 - binary_crossentropy: 1.0263 - val_loss: 14625.4546 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0695
# Epoch 33/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14477.1167 - acc: 6.5000e-04 - binary_crossentropy: 1.0241 - val_loss: 14581.3128 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0286
# Epoch 34/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14443.1833 - acc: 5.3333e-04 - binary_crossentropy: 1.0180 - val_loss: 14565.3331 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0427
# Epoch 35/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14410.7610 - acc: 6.5000e-04 - binary_crossentropy: 1.0168 - val_loss: 14562.2709 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9849
# Epoch 36/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14382.3006 - acc: 6.3333e-04 - binary_crossentropy: 1.0092 - val_loss: 14509.6368 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0342
# Epoch 37/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14350.1965 - acc: 5.6667e-04 - binary_crossentropy: 1.0083 - val_loss: 14487.8548 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0139
# Epoch 38/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14321.5089 - acc: 6.5000e-04 - binary_crossentropy: 1.0045 - val_loss: 14465.7044 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0167
# Epoch 39/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14291.3543 - acc: 5.3333e-04 - binary_crossentropy: 1.0009 - val_loss: 14455.7359 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9755
# Epoch 40/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14263.8933 - acc: 5.5000e-04 - binary_crossentropy: 0.9957 - val_loss: 14431.8246 - val_acc: 3.0000e-04 - val_binary_crossentropy: 1.0300
# Epoch 41/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14237.3235 - acc: 6.3333e-04 - binary_crossentropy: 0.9940 - val_loss: 14429.5265 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0496
# Epoch 42/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14212.5225 - acc: 5.6667e-04 - binary_crossentropy: 0.9932 - val_loss: 14365.4944 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9974
# Epoch 43/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14185.6220 - acc: 6.3333e-04 - binary_crossentropy: 0.9889 - val_loss: 14346.4345 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9938
# Epoch 44/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14159.9859 - acc: 4.5000e-04 - binary_crossentropy: 0.9868 - val_loss: 14320.9304 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0036
# Epoch 45/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14134.7587 - acc: 6.0000e-04 - binary_crossentropy: 0.9851 - val_loss: 14313.4445 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9929
# Epoch 46/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14113.7802 - acc: 5.5000e-04 - binary_crossentropy: 0.9825 - val_loss: 14296.3350 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9975
# Epoch 47/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14088.9326 - acc: 5.8333e-04 - binary_crossentropy: 0.9803 - val_loss: 14278.6486 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9737
# Epoch 48/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14066.6708 - acc: 6.8333e-04 - binary_crossentropy: 0.9779 - val_loss: 14276.8597 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0191
# Epoch 49/100
# 600/600 [==============================] - 13s 22ms/step - loss: 14044.9425 - acc: 5.1667e-04 - binary_crossentropy: 0.9762 - val_loss: 14273.6417 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.0163
# Epoch 50/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14023.7930 - acc: 5.8333e-04 - binary_crossentropy: 0.9757 - val_loss: 14232.5408 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0098
# Epoch 51/100
# 600/600 [==============================] - 13s 21ms/step - loss: 14004.9480 - acc: 5.6667e-04 - binary_crossentropy: 0.9743 - val_loss: 14224.7982 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9905
# Epoch 52/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13982.4093 - acc: 5.6667e-04 - binary_crossentropy: 0.9717 - val_loss: 14195.5482 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9986
# Epoch 53/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13960.0939 - acc: 5.3333e-04 - binary_crossentropy: 0.9695 - val_loss: 14180.5339 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9840
# Epoch 54/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13941.6690 - acc: 5.3333e-04 - binary_crossentropy: 0.9682 - val_loss: 14176.0684 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9927
# Epoch 55/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13922.3288 - acc: 6.0000e-04 - binary_crossentropy: 0.9681 - val_loss: 14156.2217 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9804
# Epoch 56/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13903.7774 - acc: 6.0000e-04 - binary_crossentropy: 0.9652 - val_loss: 14140.5269 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9809
# Epoch 57/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13881.8430 - acc: 5.8333e-04 - binary_crossentropy: 0.9627 - val_loss: 14130.1824 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0031
# Epoch 58/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13866.4701 - acc: 5.0000e-04 - binary_crossentropy: 0.9628 - val_loss: 14120.4675 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9935
# Epoch 59/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13848.5120 - acc: 5.5000e-04 - binary_crossentropy: 0.9621 - val_loss: 14094.6794 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9633
# Epoch 60/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13829.2440 - acc: 4.1667e-04 - binary_crossentropy: 0.9592 - val_loss: 14073.7378 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9893
# Epoch 61/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13813.7017 - acc: 5.0000e-04 - binary_crossentropy: 0.9578 - val_loss: 14085.8836 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9968
# Epoch 62/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13798.3283 - acc: 4.6667e-04 - binary_crossentropy: 0.9577 - val_loss: 14059.0714 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9852
# Epoch 63/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13777.9641 - acc: 5.0000e-04 - binary_crossentropy: 0.9554 - val_loss: 14050.5588 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9869
# Epoch 64/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13761.4190 - acc: 4.5000e-04 - binary_crossentropy: 0.9540 - val_loss: 14030.4157 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9813
# Epoch 65/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13744.5166 - acc: 4.5000e-04 - binary_crossentropy: 0.9531 - val_loss: 14024.4733 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9756
# Epoch 66/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13731.8220 - acc: 4.5000e-04 - binary_crossentropy: 0.9521 - val_loss: 14030.2327 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9902
# Epoch 67/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13715.1649 - acc: 3.6667e-04 - binary_crossentropy: 0.9504 - val_loss: 13997.2894 - val_acc: 9.0000e-04 - val_binary_crossentropy: 0.9792
# Epoch 68/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13696.7255 - acc: 4.6667e-04 - binary_crossentropy: 0.9490 - val_loss: 14009.3865 - val_acc: 8.0000e-04 - val_binary_crossentropy: 0.9875
# Epoch 69/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13686.6446 - acc: 4.3333e-04 - binary_crossentropy: 0.9480 - val_loss: 13988.1459 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9754
# Epoch 70/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13669.1737 - acc: 3.8333e-04 - binary_crossentropy: 0.9476 - val_loss: 13985.4209 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9606
# Epoch 71/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13655.5636 - acc: 4.3333e-04 - binary_crossentropy: 0.9451 - val_loss: 13956.8776 - val_acc: 9.0000e-04 - val_binary_crossentropy: 0.9727
# Epoch 72/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13639.5698 - acc: 4.6667e-04 - binary_crossentropy: 0.9441 - val_loss: 13970.3766 - val_acc: 9.0000e-04 - val_binary_crossentropy: 0.9876
# Epoch 73/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13627.1246 - acc: 4.8333e-04 - binary_crossentropy: 0.9438 - val_loss: 13938.8550 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9556
# Epoch 74/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13612.1033 - acc: 4.8333e-04 - binary_crossentropy: 0.9421 - val_loss: 13933.6477 - val_acc: 8.0000e-04 - val_binary_crossentropy: 0.9683
# Epoch 75/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13599.5208 - acc: 3.1667e-04 - binary_crossentropy: 0.9406 - val_loss: 13932.1289 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9780
# Epoch 76/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13584.2992 - acc: 3.3333e-04 - binary_crossentropy: 0.9404 - val_loss: 13920.7127 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9636
# Epoch 77/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13571.5237 - acc: 3.8333e-04 - binary_crossentropy: 0.9385 - val_loss: 13906.8127 - val_acc: 9.0000e-04 - val_binary_crossentropy: 0.9769
# Epoch 78/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13558.0944 - acc: 3.5000e-04 - binary_crossentropy: 0.9382 - val_loss: 13895.5593 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9631
# Epoch 79/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13546.6566 - acc: 3.6667e-04 - binary_crossentropy: 0.9366 - val_loss: 13875.3350 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9592
# Epoch 80/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13531.7372 - acc: 4.0000e-04 - binary_crossentropy: 0.9355 - val_loss: 13885.4026 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9594
# Epoch 81/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13516.0611 - acc: 4.1667e-04 - binary_crossentropy: 0.9342 - val_loss: 13865.3976 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9706
# Epoch 82/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13505.3076 - acc: 3.5000e-04 - binary_crossentropy: 0.9343 - val_loss: 13861.9537 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9690
# Epoch 83/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13492.6980 - acc: 2.6667e-04 - binary_crossentropy: 0.9329 - val_loss: 13848.2812 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9613
# Epoch 84/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13481.3089 - acc: 3.5000e-04 - binary_crossentropy: 0.9309 - val_loss: 13845.6340 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9697
# Epoch 85/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13468.3669 - acc: 3.3333e-04 - binary_crossentropy: 0.9313 - val_loss: 13837.5307 - val_acc: 9.0000e-04 - val_binary_crossentropy: 0.9514
# Epoch 86/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13456.2200 - acc: 3.0000e-04 - binary_crossentropy: 0.9306 - val_loss: 13848.4909 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9255
# Epoch 87/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13442.7601 - acc: 2.3333e-04 - binary_crossentropy: 0.9283 - val_loss: 13821.0555 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9633
# Epoch 88/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13433.0344 - acc: 2.3333e-04 - binary_crossentropy: 0.9277 - val_loss: 13805.3816 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9549
# Epoch 89/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13421.4737 - acc: 2.6667e-04 - binary_crossentropy: 0.9272 - val_loss: 13799.6949 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9515
# Epoch 90/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13411.0452 - acc: 3.0000e-04 - binary_crossentropy: 0.9265 - val_loss: 13790.4390 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9523
# Epoch 91/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13399.3486 - acc: 3.1667e-04 - binary_crossentropy: 0.9255 - val_loss: 13788.0930 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9540
# Epoch 92/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13390.4540 - acc: 3.1667e-04 - binary_crossentropy: 0.9249 - val_loss: 13776.8214 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9505
# Epoch 93/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13378.4048 - acc: 2.8333e-04 - binary_crossentropy: 0.9242 - val_loss: 13775.5779 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9456
# Epoch 94/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13368.2599 - acc: 3.5000e-04 - binary_crossentropy: 0.9223 - val_loss: 13777.3890 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9672
# Epoch 95/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13357.9104 - acc: 4.5000e-04 - binary_crossentropy: 0.9225 - val_loss: 13764.8223 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9752
# Epoch 96/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13346.2904 - acc: 2.1667e-04 - binary_crossentropy: 0.9223 - val_loss: 13756.0065 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9536
# Epoch 97/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13338.4138 - acc: 3.1667e-04 - binary_crossentropy: 0.9194 - val_loss: 13753.0953 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9692
# Epoch 98/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13327.2814 - acc: 3.1667e-04 - binary_crossentropy: 0.9201 - val_loss: 13746.5957 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9511
# Epoch 99/100
# 600/600 [==============================] - 13s 22ms/step - loss: 13322.1779 - acc: 2.6667e-04 - binary_crossentropy: 0.9199 - val_loss: 13742.4852 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9396
# Epoch 100/100
# 600/600 [==============================] - 13s 21ms/step - loss: 13310.6383 - acc: 3.0000e-04 - binary_crossentropy: 0.9183 - val_loss: 13741.7053 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9531

# %% [markdown]
# ### Generate some samples
# **NOTE:** Need to think about what model architecture best suits my purposes
# * The model below makes pretty rough looking samples
# * Based on how the loss looks, the model training is okay
# * Think about principled stopping conditions etc. for reproduceable usage in downstream CIT
# * Think how (if at all) loss changes in genotype case, i.e. is binary crossentropy suitable?
# * Think about how model architecture should change for "better" latent space

# %%
import matplotlib.pyplot as plt
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16,10))

    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                       '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
                 label=name.title()+' Train')

    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])

plot_history([("base_line", train_history)])
plot_history([("base_line", train_history)], key='loss')
plot_history([("base_line", train_history)], key = 'acc')


fig = plt.figure(figsize=(5,5))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(tf.reshape(model.sample(eps = tf.random.normal(shape = (1,2))),(28,28)),cmap="gray")
    plt.axis('off')
plt.show()

# %%
model.save_weights("/home/wcasazza/projects/def-saram/wcasazza/vaecit/scripts/mnist_test_weights.h5")
