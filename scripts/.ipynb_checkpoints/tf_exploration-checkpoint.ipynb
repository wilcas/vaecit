# %% [markdown]
# # Exploring tensorflow
# I am getting confused when manipulating examples using tensorflow, so I am going to try to build up a VAE and train it line by line instead.

# %%
import tensorflow as tf
import numpy as np
tf.enable_eager_execution()

# %% [markdown]
# ## VAE module
# The variational autoencoder will expect a genotype vector as input. The idea is to learn genotype-set specific information from a sample by reducing it and then building it back up from a random generator. the structure of the program will be as follows:
#
# 1. VAE class
#     1. Model structure
#     1. training methods
# 1. example data training
# 1. data output

# %%
class VAE(tf.keras.Model):
    
    def __init__(self, n_latent=2, output_size=10): # default 2 latent dimensions
        super(VAE,self).__init__() # inherit Model functions
        self.n_latent=n_latent
        self.encode_net = tf.keras.Sequential(
            [
                tf.keras.layers.Dense(128,activation=tf.nn.relu),
                tf.keras.layers.Dense(256,activation=tf.nn.relu),
                tf.keras.layers.Dense(2*n_latent) #no Activation
            ]
        )
        self.decode_net = tf.keras.Sequential(
            [
                tf.keras.layers.InputLayer(input_shape=(n_latent,)),
                tf.keras.layers.Dense(256,activation=tf.nn.relu),
                tf.keras.layers.Dense(128,activation=tf.nn.relu),
                tf.keras.layers.Dense(output_size) #no Activation
            ]
        )
    
    def call(self, data):
        mean,logvar = self.encode(data)
        z = self.reparameterize(mean, logvar)
        return self.decode(z)

    def sample(self, eps=None):
        if eps is None:
            eps = tf.random.normal(shape=(100, self.n_latent))
        return self.decode(eps, apply_sigmoid=True)

    def encode(self, x):
        mean, logvar = tf.split(self.encode_net(x), num_or_size_splits=2, axis=1)
        return mean, logvar

    def reparameterize(self, mean, logvar):
        eps = tf.random.normal(shape=mean.shape)
        return eps * tf.exp(logvar * .5) + mean

    def decode(self, z, apply_sigmoid = False):
        logits = self.decode_net(z)
        if apply_sigmoid:
            return tf.sigmoid(logits)
        else:
            return logits
        
    def total_loss(self, x,y):
        mean, logvar = self.encode(x)
        z = self.reparameterize(mean, logvar)
        x_logit = self.decode(z)

        cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
        logpx_z = -tf.reduce_sum(cross_ent)
        logpz = log_normal_pdf(z, 0., 0.)
        logqz_x = log_normal_pdf(z, mean, logvar)
        return -tf.reduce_mean(logpx_z + logpz - logqz_x)
    
def log_normal_pdf(sample, mean, logvar, raxis=1):
    log2pi = tf.math.log(2. * np.pi)
    return tf.reduce_sum(
        -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
        axis=raxis
    )

# %% [markdown]
# ### Generate some data

# %%
(train_images, _), (test_images, _) = tf.keras.datasets.mnist.load_data()
train_images = train_images.astype('float32') / 255
train_images = train_images.reshape((train_images.shape[0], 28 * 28))
test_images = test_images.astype('float32') / 255
test_images = test_images.reshape((test_images.shape[0], 28 * 28))

# Binarization
train_images[train_images >= .5] = 1.
train_images[train_images < .5] = 0.
test_images[test_images >= .5] = 1.
test_images[test_images < .5] = 0.



# train_data = np.random.binomial(2,0.25, size=(10000,1000)).astype(np.float32)
# test_data = np.random.binomial(2,0.25, size=(10000,1000)).astype(np.float32)

# %% [markdown]
# ### Training
# Only 3 lines!

# %%
model = VAE(n_latent=2, output_size=28*28)
model.compile(loss = model.total_loss, optimizer = tf.train.AdamOptimizer(1e-4), metrics=['accuracy', 'binary_crossentropy'])

# %%
train_history = model.fit(train_images,train_images, epochs=100, batch_size=100,validation_data=(test_images, test_images), callbacks=[tf.keras.callbacks.TensorBoard()])
# Out:
# Epoch 1/100
# 600/600 [==============================] - 12s 20ms/step - loss: 26387.8622 - acc: 0.0013 - binary_crossentropy: 1.6991 - val_loss: 20334.7874 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.8471
# Epoch 2/100
# 600/600 [==============================] - 12s 21ms/step - loss: 19966.7594 - acc: 0.0000e+00 - binary_crossentropy: 1.8199 - val_loss: 19650.8137 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.9146
# Epoch 3/100
# 600/600 [==============================] - 13s 21ms/step - loss: 19501.4769 - acc: 1.3333e-04 - binary_crossentropy: 1.8568 - val_loss: 19197.2596 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.8612
# Epoch 4/100
# 600/600 [==============================] - 13s 21ms/step - loss: 18725.1020 - acc: 9.5000e-04 - binary_crossentropy: 1.6648 - val_loss: 18108.1979 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.4815
# Epoch 5/100
# 600/600 [==============================] - 13s 21ms/step - loss: 18039.5621 - acc: 0.0000e+00 - binary_crossentropy: 1.4643 - val_loss: 17809.6593 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.5287
# Epoch 6/100
# 600/600 [==============================] - 13s 22ms/step - loss: 17714.1379 - acc: 0.0000e+00 - binary_crossentropy: 1.4284 - val_loss: 17477.4451 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.4071
# Epoch 7/100
# 600/600 [==============================] - 13s 22ms/step - loss: 17338.6259 - acc: 0.0000e+00 - binary_crossentropy: 1.4047 - val_loss: 17081.5702 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3493
# Epoch 8/100
# 600/600 [==============================] - 14s 23ms/step - loss: 17000.0870 - acc: 0.0000e+00 - binary_crossentropy: 1.3897 - val_loss: 16816.4544 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3798
# Epoch 9/100
# 600/600 [==============================] - 14s 23ms/step - loss: 16759.4613 - acc: 0.0000e+00 - binary_crossentropy: 1.3862 - val_loss: 16664.0417 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.4346
# Epoch 10/100
# 600/600 [==============================] - 14s 23ms/step - loss: 16570.4522 - acc: 1.6667e-05 - binary_crossentropy: 1.3792 - val_loss: 16461.0852 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3546
# Epoch 11/100
# 600/600 [==============================] - 14s 23ms/step - loss: 16415.1632 - acc: 0.0000e+00 - binary_crossentropy: 1.3646 - val_loss: 16333.1502 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3820
# Epoch 12/100
# 600/600 [==============================] - 15s 25ms/step - loss: 16271.7912 - acc: 5.0000e-05 - binary_crossentropy: 1.3456 - val_loss: 16190.5058 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3360
# Epoch 13/100
# 600/600 [==============================] - 15s 24ms/step - loss: 16125.1894 - acc: 3.3333e-05 - binary_crossentropy: 1.3174 - val_loss: 16038.4810 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.3071
# Epoch 14/100
# 600/600 [==============================] - 15s 25ms/step - loss: 15983.6308 - acc: 0.0000e+00 - binary_crossentropy: 1.2884 - val_loss: 15909.6510 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.2917
# Epoch 15/100
# 600/600 [==============================] - 14s 24ms/step - loss: 15853.9828 - acc: 3.3333e-05 - binary_crossentropy: 1.2598 - val_loss: 15806.8375 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.2808
# Epoch 16/100
# 600/600 [==============================] - 15s 26ms/step - loss: 15737.9711 - acc: 1.1667e-04 - binary_crossentropy: 1.2356 - val_loss: 15701.6325 - val_acc: 0.0000e+00 - val_binary_crossentropy: 1.2540
# Epoch 17/100
# 600/600 [==============================] - 15s 25ms/step - loss: 15637.6773 - acc: 1.6667e-04 - binary_crossentropy: 1.2170 - val_loss: 15622.7837 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.2435
# Epoch 18/100
# 600/600 [==============================] - 15s 25ms/step - loss: 15554.9781 - acc: 3.5000e-04 - binary_crossentropy: 1.2006 - val_loss: 15572.9337 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.2256
# Epoch 19/100
# 600/600 [==============================] - 15s 25ms/step - loss: 15478.9803 - acc: 8.1667e-04 - binary_crossentropy: 1.1867 - val_loss: 15480.6607 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.1571
# Epoch 20/100
# 600/600 [==============================] - 16s 26ms/step - loss: 15413.9230 - acc: 9.8333e-04 - binary_crossentropy: 1.1712 - val_loss: 15434.7401 - val_acc: 9.0000e-04 - val_binary_crossentropy: 1.1891
# Epoch 21/100
# 600/600 [==============================] - 16s 26ms/step - loss: 15348.2094 - acc: 0.0011 - binary_crossentropy: 1.1618 - val_loss: 15369.7218 - val_acc: 9.0000e-04 - val_binary_crossentropy: 1.1554
# Epoch 22/100
# 600/600 [==============================] - 16s 26ms/step - loss: 15287.8068 - acc: 0.0011 - binary_crossentropy: 1.1463 - val_loss: 15322.5478 - val_acc: 0.0015 - val_binary_crossentropy: 1.1555
# Epoch 23/100
# 600/600 [==============================] - 16s 27ms/step - loss: 15231.4929 - acc: 0.0012 - binary_crossentropy: 1.1362 - val_loss: 15265.1383 - val_acc: 9.0000e-04 - val_binary_crossentropy: 1.1337
# Epoch 24/100
# 600/600 [==============================] - 17s 28ms/step - loss: 15173.7123 - acc: 0.0012 - binary_crossentropy: 1.1224 - val_loss: 15216.9838 - val_acc: 9.0000e-04 - val_binary_crossentropy: 1.1396
# Epoch 25/100
# 600/600 [==============================] - 16s 27ms/step - loss: 15114.7829 - acc: 0.0011 - binary_crossentropy: 1.1134 - val_loss: 15188.0229 - val_acc: 0.0012 - val_binary_crossentropy: 1.1519
# Epoch 26/100
# 600/600 [==============================] - 17s 28ms/step - loss: 15057.6088 - acc: 9.0000e-04 - binary_crossentropy: 1.1048 - val_loss: 15102.6167 - val_acc: 0.0011 - val_binary_crossentropy: 1.0981
# Epoch 27/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14995.9805 - acc: 9.3333e-04 - binary_crossentropy: 1.0933 - val_loss: 15055.2492 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.1165
# Epoch 28/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14940.3529 - acc: 9.3333e-04 - binary_crossentropy: 1.0861 - val_loss: 14990.6665 - val_acc: 0.0011 - val_binary_crossentropy: 1.0990
# Epoch 29/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14882.2731 - acc: 9.3333e-04 - binary_crossentropy: 1.0800 - val_loss: 14942.5526 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.0771
# Epoch 30/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14827.2044 - acc: 0.0010 - binary_crossentropy: 1.0718 - val_loss: 14907.0612 - val_acc: 0.0011 - val_binary_crossentropy: 1.1183
# Epoch 31/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14772.6863 - acc: 8.8333e-04 - binary_crossentropy: 1.0670 - val_loss: 14849.2231 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.1019
# Epoch 32/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14723.2391 - acc: 8.6667e-04 - binary_crossentropy: 1.0613 - val_loss: 14807.1682 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0692
# Epoch 33/100
# 600/600 [==============================] - 18s 30ms/step - loss: 14678.6326 - acc: 6.8333e-04 - binary_crossentropy: 1.0535 - val_loss: 14789.7070 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.0923
# Epoch 34/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14632.3903 - acc: 8.0000e-04 - binary_crossentropy: 1.0492 - val_loss: 14740.5410 - val_acc: 9.0000e-04 - val_binary_crossentropy: 1.0890
# Epoch 35/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14591.2089 - acc: 7.3333e-04 - binary_crossentropy: 1.0452 - val_loss: 14710.2949 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.0697
# Epoch 36/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14551.3249 - acc: 6.6667e-04 - binary_crossentropy: 1.0392 - val_loss: 14671.9987 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.0616
# Epoch 37/100
# 600/600 [==============================] - 18s 30ms/step - loss: 14512.5504 - acc: 6.3333e-04 - binary_crossentropy: 1.0345 - val_loss: 14641.6837 - val_acc: 7.0000e-04 - val_binary_crossentropy: 1.0746
# Epoch 38/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14478.0182 - acc: 7.8333e-04 - binary_crossentropy: 1.0298 - val_loss: 14597.4427 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0455
# Epoch 39/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14442.7543 - acc: 6.5000e-04 - binary_crossentropy: 1.0253 - val_loss: 14576.7475 - val_acc: 3.0000e-04 - val_binary_crossentropy: 1.0636
# Epoch 40/100
# 600/600 [==============================] - 20s 33ms/step - loss: 14409.1210 - acc: 6.0000e-04 - binary_crossentropy: 1.0216 - val_loss: 14556.3769 - val_acc: 2.0000e-04 - val_binary_crossentropy: 1.0673
# Epoch 41/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14376.9833 - acc: 6.0000e-04 - binary_crossentropy: 1.0188 - val_loss: 14522.9585 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.0218
# Epoch 42/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14343.5299 - acc: 6.0000e-04 - binary_crossentropy: 1.0136 - val_loss: 14499.3505 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0349
# Epoch 43/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14313.7517 - acc: 6.5000e-04 - binary_crossentropy: 1.0102 - val_loss: 14488.8586 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0452
# Epoch 44/100
# 600/600 [==============================] - 16s 27ms/step - loss: 14283.3370 - acc: 5.6667e-04 - binary_crossentropy: 1.0057 - val_loss: 14447.9802 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0338
# Epoch 45/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14253.5731 - acc: 5.6667e-04 - binary_crossentropy: 1.0033 - val_loss: 14444.6530 - val_acc: 1.0000e-03 - val_binary_crossentropy: 1.0285
# Epoch 46/100
# 600/600 [==============================] - 18s 29ms/step - loss: 14226.8414 - acc: 5.8333e-04 - binary_crossentropy: 0.9993 - val_loss: 14404.9940 - val_acc: 3.0000e-04 - val_binary_crossentropy: 1.0046
# Epoch 47/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14196.1461 - acc: 5.8333e-04 - binary_crossentropy: 0.9949 - val_loss: 14395.4117 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.0128
# Epoch 48/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14168.1289 - acc: 7.0000e-04 - binary_crossentropy: 0.9921 - val_loss: 14382.3492 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0067
# Epoch 49/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14142.1842 - acc: 7.1667e-04 - binary_crossentropy: 0.9893 - val_loss: 14357.7578 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9976
# Epoch 50/100
# 600/600 [==============================] - 16s 27ms/step - loss: 14116.0954 - acc: 7.0000e-04 - binary_crossentropy: 0.9851 - val_loss: 14343.8946 - val_acc: 8.0000e-04 - val_binary_crossentropy: 1.0113
# Epoch 51/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14094.5949 - acc: 6.6667e-04 - binary_crossentropy: 0.9837 - val_loss: 14316.8758 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9968
# Epoch 52/100
# 600/600 [==============================] - 17s 29ms/step - loss: 14067.0190 - acc: 7.1667e-04 - binary_crossentropy: 0.9793 - val_loss: 14320.8318 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.0236
# Epoch 53/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14042.6555 - acc: 6.1667e-04 - binary_crossentropy: 0.9780 - val_loss: 14286.7278 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9939
# Epoch 54/100
# 600/600 [==============================] - 17s 28ms/step - loss: 14020.0058 - acc: 6.8333e-04 - binary_crossentropy: 0.9748 - val_loss: 14271.4677 - val_acc: 8.0000e-04 - val_binary_crossentropy: 0.9946
# Epoch 55/100
# 600/600 [==============================] - 16s 27ms/step - loss: 13999.8629 - acc: 6.1667e-04 - binary_crossentropy: 0.9733 - val_loss: 14267.7901 - val_acc: 7.0000e-04 - val_binary_crossentropy: 0.9980
# Epoch 56/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13977.7378 - acc: 6.6667e-04 - binary_crossentropy: 0.9701 - val_loss: 14270.5250 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0249
# Epoch 57/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13955.9271 - acc: 5.8333e-04 - binary_crossentropy: 0.9693 - val_loss: 14234.6627 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9953
# Epoch 58/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13935.3749 - acc: 5.6667e-04 - binary_crossentropy: 0.9674 - val_loss: 14233.5516 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9679
# Epoch 59/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13914.2397 - acc: 6.0000e-04 - binary_crossentropy: 0.9646 - val_loss: 14200.8243 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9800
# Epoch 60/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13893.8743 - acc: 5.8333e-04 - binary_crossentropy: 0.9626 - val_loss: 14191.8420 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9967
# Epoch 61/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13875.7747 - acc: 5.6667e-04 - binary_crossentropy: 0.9616 - val_loss: 14183.6873 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9961
# Epoch 62/100
# 600/600 [==============================] - 16s 27ms/step - loss: 13857.0039 - acc: 5.8333e-04 - binary_crossentropy: 0.9601 - val_loss: 14170.1088 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9887
# Epoch 63/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13838.3124 - acc: 5.8333e-04 - binary_crossentropy: 0.9588 - val_loss: 14165.8290 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9807
# Epoch 64/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13821.7512 - acc: 5.6667e-04 - binary_crossentropy: 0.9564 - val_loss: 14145.7579 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9805
# Epoch 65/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13802.4605 - acc: 5.1667e-04 - binary_crossentropy: 0.9545 - val_loss: 14171.7625 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0207
# Epoch 66/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13788.6081 - acc: 4.6667e-04 - binary_crossentropy: 0.9555 - val_loss: 14126.1916 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9778
# Epoch 67/100
# 600/600 [==============================] - 16s 27ms/step - loss: 13770.7145 - acc: 5.8333e-04 - binary_crossentropy: 0.9534 - val_loss: 14119.4004 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9685
# Epoch 68/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13753.6115 - acc: 5.3333e-04 - binary_crossentropy: 0.9514 - val_loss: 14107.7032 - val_acc: 6.0000e-04 - val_binary_crossentropy: 0.9879
# Epoch 69/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13740.3137 - acc: 6.0000e-04 - binary_crossentropy: 0.9513 - val_loss: 14095.0984 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9705
# Epoch 70/100
# 600/600 [==============================] - 18s 29ms/step - loss: 13727.2697 - acc: 4.5000e-04 - binary_crossentropy: 0.9492 - val_loss: 14097.9862 - val_acc: 5.0000e-04 - val_binary_crossentropy: 1.0059
# Epoch 71/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13709.0700 - acc: 4.5000e-04 - binary_crossentropy: 0.9491 - val_loss: 14080.5317 - val_acc: 1.0000e-04 - val_binary_crossentropy: 0.9764
# Epoch 72/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13697.1957 - acc: 4.8333e-04 - binary_crossentropy: 0.9482 - val_loss: 14080.6920 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9645
# Epoch 73/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13680.8136 - acc: 3.8333e-04 - binary_crossentropy: 0.9461 - val_loss: 14064.8945 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9851
# Epoch 74/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13666.6560 - acc: 4.5000e-04 - binary_crossentropy: 0.9461 - val_loss: 14054.1567 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9873
# Epoch 75/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13653.8714 - acc: 5.0000e-04 - binary_crossentropy: 0.9447 - val_loss: 14059.4578 - val_acc: 4.0000e-04 - val_binary_crossentropy: 1.0028
# Epoch 76/100
# 600/600 [==============================] - 18s 29ms/step - loss: 13642.7921 - acc: 4.8333e-04 - binary_crossentropy: 0.9443 - val_loss: 14040.9201 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9997
# Epoch 77/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13629.7881 - acc: 4.5000e-04 - binary_crossentropy: 0.9447 - val_loss: 14033.2680 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9801
# Epoch 78/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13615.8652 - acc: 4.5000e-04 - binary_crossentropy: 0.9415 - val_loss: 14019.9684 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9782
# Epoch 79/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13603.6253 - acc: 4.8333e-04 - binary_crossentropy: 0.9426 - val_loss: 14020.2449 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9925
# Epoch 80/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13592.0552 - acc: 3.6667e-04 - binary_crossentropy: 0.9419 - val_loss: 14005.3028 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9553
# Epoch 81/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13579.8721 - acc: 3.8333e-04 - binary_crossentropy: 0.9394 - val_loss: 14003.8744 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9889
# Epoch 82/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13568.2351 - acc: 3.0000e-04 - binary_crossentropy: 0.9396 - val_loss: 13996.1740 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9811
# Epoch 83/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13559.4427 - acc: 3.0000e-04 - binary_crossentropy: 0.9388 - val_loss: 13993.9889 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9762
# Epoch 84/100
# 600/600 [==============================] - 18s 29ms/step - loss: 13547.4591 - acc: 3.0000e-04 - binary_crossentropy: 0.9375 - val_loss: 14003.2684 - val_acc: 6.0000e-04 - val_binary_crossentropy: 1.0074
# Epoch 85/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13537.2971 - acc: 4.1667e-04 - binary_crossentropy: 0.9386 - val_loss: 13988.5585 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9870
# Epoch 86/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13524.6992 - acc: 3.1667e-04 - binary_crossentropy: 0.9367 - val_loss: 13969.0736 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9801
# Epoch 87/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13517.3156 - acc: 3.3333e-04 - binary_crossentropy: 0.9368 - val_loss: 13962.8399 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9741
# Epoch 88/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13505.8374 - acc: 3.8333e-04 - binary_crossentropy: 0.9349 - val_loss: 13964.0997 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9823
# Epoch 89/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13493.1888 - acc: 3.6667e-04 - binary_crossentropy: 0.9352 - val_loss: 13952.4959 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9583
# Epoch 90/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13485.6875 - acc: 3.3333e-04 - binary_crossentropy: 0.9343 - val_loss: 13957.6479 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9734
# Epoch 91/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13475.8159 - acc: 3.6667e-04 - binary_crossentropy: 0.9331 - val_loss: 13960.8094 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9835
# Epoch 92/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13466.1680 - acc: 2.8333e-04 - binary_crossentropy: 0.9332 - val_loss: 13927.8775 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9622
# Epoch 93/100
# 600/600 [==============================] - 16s 27ms/step - loss: 13457.5051 - acc: 4.6667e-04 - binary_crossentropy: 0.9325 - val_loss: 13934.1686 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9720
# Epoch 94/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13447.8755 - acc: 3.5000e-04 - binary_crossentropy: 0.9314 - val_loss: 13924.5990 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9683
# Epoch 95/100
# 600/600 [==============================] - 18s 30ms/step - loss: 13438.9227 - acc: 3.3333e-04 - binary_crossentropy: 0.9317 - val_loss: 13930.2751 - val_acc: 5.0000e-04 - val_binary_crossentropy: 0.9791
# Epoch 96/100
# 600/600 [==============================] - 18s 29ms/step - loss: 13430.1529 - acc: 3.3333e-04 - binary_crossentropy: 0.9296 - val_loss: 13935.1283 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9919
# Epoch 97/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13421.1131 - acc: 2.5000e-04 - binary_crossentropy: 0.9307 - val_loss: 13901.3834 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9573
# Epoch 98/100
# 600/600 [==============================] - 17s 28ms/step - loss: 13413.5683 - acc: 3.6667e-04 - binary_crossentropy: 0.9288 - val_loss: 13905.0620 - val_acc: 4.0000e-04 - val_binary_crossentropy: 0.9650
# Epoch 99/100
# 600/600 [==============================] - 17s 29ms/step - loss: 13404.8622 - acc: 3.3333e-04 - binary_crossentropy: 0.9289 - val_loss: 13910.6292 - val_acc: 2.0000e-04 - val_binary_crossentropy: 0.9822
# Epoch 100/100
# 600/600 [==============================] - 18s 29ms/step - loss: 13396.7088 - acc: 3.3333e-04 - binary_crossentropy: 0.9286 - val_loss: 13894.9446 - val_acc: 3.0000e-04 - val_binary_crossentropy: 0.9742

# %% [markdown]
# ### Generate some samples
# **NOTE:** Need to think about what model architecture best suits my purposes
# * The model below makes pretty rough looking samples
# * Based on how the loss looks, the model training is okay
# * Think about principled stopping conditions etc. for reproduceable usage in downstream CIT
# * Think how (if at all) loss changes in genotype case, i.e. is binary crossentropy suitable?
# * Think about how model architecture should change for "better" latent space

# %%
import matplotlib.pyplot as plt
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])

plot_history([("base_line", train_history)])
fig = plt.figure(figsize=(5,5))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(tf.reshape(model.sample(eps = tf.random.normal(shape = (1,2))),(28,28)),cmap="gray")
    plt.axis('off')
plt.show()

# %%
model.save_weights("/home/wcasazza/Documents/vaecit/scripts/mnist_test_weights.h5")
